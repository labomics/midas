# %%
source("/root/workspace/code/midas/preprocess/utils.R")
setwd("/root/workspace/code/midas/")

base_dir <- "data/raw/atac+rna/sea/BM_CD34"
frag_path <- pj(base_dir, "cd34_fragments.tsv.gz")
count_path1 <- pj(base_dir, "GSM6005302_BM_CD34_Rep1_filtered_feature_bc_matrix.h5")
count_path2 <- pj(base_dir, "GSM6005304_BM_CD34_Rep2_filtered_feature_bc_matrix.h5")

output_dir <- pj(base_dir, "seurat")
mkdir(output_dir, remove_old = T)

# %%
# RNA
# load data
counts <- Read10X_h5(count_path1)
rna_counts <- counts$`Gene Expression`
rna <- gen_rna(rna_counts)
VlnPlot(rna, c("nFeature_rna", "nCount_rna", "percent.mt"), pt.size = 0.001, ncol = 3) + NoLegend()
rna
# QC
rna <- subset(rna, subset =
    nFeature_rna > 800 & nFeature_rna < 6000 &
    nCount_rna > 1100 & nCount_rna < 20000 &
    percent.mt < 25
)
VlnPlot(rna, c("nFeature_rna", "nCount_rna", "percent.mt"), pt.size = 0.001, ncol = 3, log = F) + NoLegend()
rna
rna1 <- RenameCells(rna, new.names = paste0(colnames(rna), "_1"))

# load data
counts <- Read10X_h5(count_path2)
rna_counts <- counts$`Gene Expression`
rna <- gen_rna(rna_counts)
VlnPlot(rna, c("nFeature_rna", "nCount_rna", "percent.mt"), pt.size = 0.001, ncol = 3) + NoLegend()
rna
# QC
rna <- subset(rna, subset =
    nFeature_rna > 800 & nFeature_rna < 6000 &
    nCount_rna > 1100 & nCount_rna < 20000 &
    percent.mt < 25
)
VlnPlot(rna, c("nFeature_rna", "nCount_rna", "percent.mt"), pt.size = 0.001, ncol = 3, log = F) + NoLegend()
rna
rna2 <- RenameCells(rna, new.names = paste0(colnames(rna), "_2"))

# merge two replicates
rna <- merge(rna1, rna2)
rna
# Out:
# Warning message in sparseMatrix(i = indices[] + 1, p = indptr[], x = as.numeric(x = counts[]), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Genome matrix has multiple modalities, returning a list of matrices for this genome
# An object of class Seurat
# 25165 features across 6973 samples within 1 assay
# Active assay: rna (25165 features, 0 variable features)
# plot without title
# An object of class Seurat
# 25165 features across 6494 samples within 1 assay
# Active assay: rna (25165 features, 0 variable features)
# Warning message in sparseMatrix(i = indices[] + 1, p = indptr[], x = as.numeric(x = counts[]), :
# "'giveCsparse' has been deprecated; setting 'repr = "T"' for you"
# Genome matrix has multiple modalities, returning a list of matrices for this genome
# plot without title
# An object of class Seurat
# 25568 features across 6797 samples within 1 assay
# Active assay: rna (25568 features, 0 variable features)
# plot without title
# An object of class Seurat
# 25568 features across 6348 samples within 1 assay
# Active assay: rna (25568 features, 0 variable features)
# An object of class Seurat
# 26414 features across 12842 samples within 1 assay
# Active assay: rna (26414 features, 0 variable features)
# plot without title

# %%
# ATAC
atac <- gen_atac(frag_path, cells = colnames(rna))
VlnPlot(atac, c("nCount_atac", "nucleosome_signal", "TSS.enrichment"),
        pt.size = 0.001, ncol = 3, log = T) + NoLegend()
atac
# QC
atac <- subset(atac, subset =
    nCount_atac > 1000 & nCount_atac < 4e4 &
    nucleosome_signal < 2 &
    TSS.enrichment > 2
)
atac <- subset(atac, features = rownames(atac)[rowSums(atac$atac@counts > 0) > 5])
VlnPlot(atac, c("nCount_atac", "nucleosome_signal", "TSS.enrichment"),
        pt.size = 0.001, ncol = 3, log = F) + NoLegend()
atac
# Out:
# Computing hash
#
# Extracting reads overlapping genomic regions
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from atac to atac_"
# Extracting TSS positions
#
# Extracting fragments at TSSs
#
#
# Computing TSS enrichment score
# An object of class Seurat
# 195516 features across 12842 samples within 1 assay
# Active assay: atac (195516 features, 0 variable features)
# plot without title
# An object of class Seurat
# 195503 features across 12312 samples within 1 assay
# Active assay: atac (195503 features, 0 variable features)
# plot without title

# %%
# Get intersected cells satisfying QC metrics of all modalities
cell_ids <- Reduce(intersect, list(colnames(atac), colnames(rna)))
atac <- subset(atac, cells = cell_ids)
rna <- subset(rna, cells = cell_ids)
atac
rna
# Out:
# An object of class Seurat
# 195503 features across 12312 samples within 1 assay
# Active assay: atac (195503 features, 0 variable features)
# An object of class Seurat
# 26414 features across 12312 samples within 1 assay
# Active assay: rna (26414 features, 0 variable features)

# %%
# preprocess and save data
preprocess(output_dir, atac = atac, rna = rna)
